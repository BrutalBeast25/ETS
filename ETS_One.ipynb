# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_excel('C:/Users/HP/Desktop/Data_Sets/ETS2/Transport_Data.xlsx')

# %%
data.head()
# Out:
#        Cargo Name  Cargo Weight  Transport Distance  Hour  Minutes Ferry?  \
# 0   Pressure Tank            12                2383    33       55    Yes
# 1   Post Packages            11                2029    28       49    Yes
# 2       Forklifts            11                2139    30       26    Yes
# 3      Boric Acid            16                1814    26        1    Yes
# 4  Precast Stairs            22                2147    29       28    Yes
#
#    Ferry Length  Ferry Cost Origin City Origin Country  ... Transport Type  \
# 0            60         300    Aberdeen        England  ...         Urgent
# 1            60         300    Carlisle        England  ...    Very Urgent
# 2            60         300    Aberdeen        England  ...         Normal
# 3            60         300      Vienna        Austria  ...    Very Urgent
# 4            60         300     Glasgow        England  ...    Very Urgent
#
# ...

# %%
data.isnull().sum()
# Out:
# Cargo Name             0
# Cargo Weight           0
# Transport Distance     0
# Hour                   0
# Minutes                0
# Ferry?                 0
# Ferry Length           0
# Ferry Cost             0
# Origin City            0
# Origin Country         0
# Origin Company         0
# Destination City       0
# Destination Country    0
# Destiantion Company    0
# Transport Type         0
# Trailer Type           0
# High Value Cargo       0
# Heavy Cargo            0
# Fragile Cargo          0
# ADR Cargo              0
# ADR Class & Type       0
# Special Transport      0
# Price Per KM           0
# Price                  0
# dtype: int64

# %%
data.shape
# Out:
# (740, 24)

# %%
sns.distplot(data['Price Per KM'])
plt.title('Price per KM distribution')
plt.show()
# Out:
# C:\Users\HP\NewAnaconda\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(data['Price'])
plt.title('Price distribution')
plt.show()
# Out:
# C:\Users\HP\NewAnaconda\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
fig, ax = plt.subplots()
ax.scatter(x = data['Transport Distance'], y = data['Price'])
plt.ylabel('Price', fontsize=13)
plt.xlabel('Distance', fontsize=13)
plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter(x = data['Cargo Weight'], y = data['Price'])
plt.ylabel('Price', fontsize=13)
plt.xlabel('Tons', fontsize=13)
plt.show()

# %%
sns.relplot(x='Cargo Weight',y='Price',hue='Ferry?',data=data)
plt.show()

# %%
sns.relplot(x='Transport Distance',y='Price',hue='High Value Cargo',data=data)
plt.show()

# %%
sns.relplot(x='Transport Distance',y='Price',hue='Heavy Cargo',data=data)
plt.show()

# %%
sns.relplot(x='Transport Distance',y='Price',hue='Fragile Cargo',data=data)
plt.show()

# %%
sns.relplot(x='Transport Distance',y='Price',hue='ADR Cargo',data=data)
plt.show()

# %%
sns.pairplot(data)

# %%
10*21
# Out:
# 210
